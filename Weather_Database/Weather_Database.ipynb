# %%
# Import dependencies:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Import citipy:
from citipy import citipy

# Import the requests library:
import requests

#Import API key:
from config import weather_api_key

# Import the time library and the datetime module from the datetime library:
import time
from datetime import datetime

# %%
# Create a set of random lat and long cobinations:
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list:
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities:
cities = []

# Identify the nearest city for each latitude and longitude combination:
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add to cities list:
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm: 
len(cities)
# Out:
# 722

# %%
# Starting URL for Weather Map API Call:
#https://openweathermap.org/current
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data:
city_data = []

# Print the beginning of the logging:
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters:
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list:
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes:
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city:
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city:
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count:
    record_count += 1

    # Run an API request for each of the cities:
    try:
        # Parse the JSON and retrieve data:
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data:
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard:
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list:
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description,
                          "Country": city_country})

# If an error is experienced, skip the city:
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete:
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | zyryanka
# Processing Record 3 of Set 1 | santa rosa
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | nyrob
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | sergeyevka
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | hasaki
# Processing Record 10 of Set 1 | sasovo
# Processing Record 11 of Set 1 | the valley
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | dalbandin
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | lubao
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | itarema
# Processing Record 27 of Set 1 | don marcelino
# City not found. Skipping...
# Processing Record 28 of Set 1 | taoudenni
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | limbach-oberfrohna
# Processing Record 32 of Set 1 | bilma
# Processing Record 33 of Set 1 | alugan
# Processing Record 34 of Set 1 | pringsewu
# Processing Record 35 of Set 1 | sao filipe
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | launceston
# Processing Record 38 of Set 1 | hami
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | limbang
# Processing Record 42 of Set 1 | belaya gora
# Processing Record 43 of Set 1 | port moresby
# Processing Record 44 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | oda
# Processing Record 50 of Set 1 | goundam
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | high level
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | angra
# City not found. Skipping...
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | muli
# Processing Record 14 of Set 2 | quatre cocos
# Processing Record 15 of Set 2 | brae
# Processing Record 16 of Set 2 | ilulissat
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | mayo
# Processing Record 19 of Set 2 | mountain home
# Processing Record 20 of Set 2 | flinders
# Processing Record 21 of Set 2 | hukuntsi
# Processing Record 22 of Set 2 | koumac
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | moengo
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | saku
# Processing Record 30 of Set 2 | dunedin
# Processing Record 31 of Set 2 | kutum
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | pangody
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | kudahuvadhoo
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | bonavista
# Processing Record 39 of Set 2 | san marco in lamis
# Processing Record 40 of Set 2 | antalaha
# Processing Record 41 of Set 2 | taltal
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | margate
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 2 | yumen
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | pangnirtung
# Processing Record 1 of Set 3 | erzin
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | cochrane
# Processing Record 4 of Set 3 | bassano
# Processing Record 5 of Set 3 | shimoda
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | monaghan
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | samdari
# Processing Record 11 of Set 3 | tilichiki
# Processing Record 12 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 3 | giovinazzo
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | chake chake
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | mataura
# Processing Record 18 of Set 3 | tarauaca
# Processing Record 19 of Set 3 | liverpool
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | asau
# Processing Record 22 of Set 3 | padang
# Processing Record 23 of Set 3 | labuhan
# Processing Record 24 of Set 3 | severo-kurilsk
# Processing Record 25 of Set 3 | ogbomosho
# Processing Record 26 of Set 3 | khatanga
# Processing Record 27 of Set 3 | huazolotitlan
# City not found. Skipping...
# Processing Record 28 of Set 3 | chinhoyi
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | kenai
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | tias
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | kodinar
# Processing Record 39 of Set 3 | ngunguru
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | sal rei
# Processing Record 43 of Set 3 | beloha
# Processing Record 44 of Set 3 | hirara
# Processing Record 45 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 3 | arman
# Processing Record 47 of Set 3 | san ignacio
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | laguna
# Processing Record 50 of Set 3 | prince rupert
# Processing Record 1 of Set 4 | luderitz
# Processing Record 2 of Set 4 | sept-iles
# Processing Record 3 of Set 4 | huaraz
# Processing Record 4 of Set 4 | alofi
# Processing Record 5 of Set 4 | cururupu
# Processing Record 6 of Set 4 | lorengau
# Processing Record 7 of Set 4 | poum
# Processing Record 8 of Set 4 | terney
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | omboue
# Processing Record 11 of Set 4 | agadez
# Processing Record 12 of Set 4 | san patricio
# Processing Record 13 of Set 4 | matamoros
# Processing Record 14 of Set 4 | port-gentil
# Processing Record 15 of Set 4 | savonlinna
# Processing Record 16 of Set 4 | turukhansk
# Processing Record 17 of Set 4 | malyye derbety
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | rio bueno
# Processing Record 20 of Set 4 | abancay
# Processing Record 21 of Set 4 | jabinyanah
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | bikaner
# Processing Record 24 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | cacu
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | rocha
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | omsukchan
# Processing Record 31 of Set 4 | ust-tsilma
# Processing Record 32 of Set 4 | zhanaozen
# Processing Record 33 of Set 4 | kaitangata
# Processing Record 34 of Set 4 | vestmanna
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | erdenet
# Processing Record 37 of Set 4 | fernley
# Processing Record 38 of Set 4 | corrente
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | dubbo
# Processing Record 41 of Set 4 | ostrovnoy
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | kichera
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | carutapera
# Processing Record 46 of Set 4 | georgetown
# Processing Record 47 of Set 4 | durban
# Processing Record 48 of Set 4 | majalengka
# Processing Record 49 of Set 4 | talcahuano
# Processing Record 50 of Set 4 | yei
# Processing Record 1 of Set 5 | vanimo
# Processing Record 2 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 5 | kota belud
# Processing Record 4 of Set 5 | kosh-agach
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | olinda
# Processing Record 7 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | tulare
# Processing Record 10 of Set 5 | vila franca do campo
# Processing Record 11 of Set 5 | posadas
# Processing Record 12 of Set 5 | mahibadhoo
# Processing Record 13 of Set 5 | victoria
# Processing Record 14 of Set 5 | benghazi
# Processing Record 15 of Set 5 | merauke
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | antofagasta
# Processing Record 18 of Set 5 | lebyazhye
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | aleksandrovskiy zavod
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | kumluca
# Processing Record 23 of Set 5 | tuatapere
# Processing Record 24 of Set 5 | talara
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | karasburg
# Processing Record 27 of Set 5 | sitka
# Processing Record 28 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | hammerfest
# Processing Record 31 of Set 5 | sirjan
# Processing Record 32 of Set 5 | mbini
# Processing Record 33 of Set 5 | korla
# Processing Record 34 of Set 5 | ugoofaaru
# Processing Record 35 of Set 5 | harper
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | kuching
# Processing Record 40 of Set 5 | raesfeld
# Processing Record 41 of Set 5 | guerrero negro
# Processing Record 42 of Set 5 | natchez
# Processing Record 43 of Set 5 | belyy yar
# Processing Record 44 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 5 | bialogard
# Processing Record 46 of Set 5 | victoria point
# Processing Record 47 of Set 5 | ilinskoye-khovanskoye
# Processing Record 48 of Set 5 | broken hill
# Processing Record 49 of Set 5 | svetlogorsk
# Processing Record 50 of Set 5 | tukrah
# Processing Record 1 of Set 6 | kamskoye ustye
# Processing Record 2 of Set 6 | voyinka
# Processing Record 3 of Set 6 | saint-fabien
# City not found. Skipping...
# Processing Record 4 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 5 of Set 6 | wakkanai
# Processing Record 6 of Set 6 | stromness
# Processing Record 7 of Set 6 | namie
# Processing Record 8 of Set 6 | karaton
# Processing Record 9 of Set 6 | ancud
# Processing Record 10 of Set 6 | saint-pierre
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | chulman
# Processing Record 13 of Set 6 | calvinia
# Processing Record 14 of Set 6 | rawson
# Processing Record 15 of Set 6 | souillac
# Processing Record 16 of Set 6 | honiara
# Processing Record 17 of Set 6 | pevek
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | bosaso
# Processing Record 20 of Set 6 | roald
# Processing Record 21 of Set 6 | manzhouli
# Processing Record 22 of Set 6 | yinchuan
# Processing Record 23 of Set 6 | miranda
# Processing Record 24 of Set 6 | verkhoyansk
# Processing Record 25 of Set 6 | thinadhoo
# Processing Record 26 of Set 6 | grand gaube
# Processing Record 27 of Set 6 | asadabad
# Processing Record 28 of Set 6 | bahia blanca
# Processing Record 29 of Set 6 | la rioja
# Processing Record 30 of Set 6 | opuwo
# Processing Record 31 of Set 6 | zhigansk
# Processing Record 32 of Set 6 | samarinda
# Processing Record 33 of Set 6 | san antonio
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | eureka
# Processing Record 37 of Set 6 | samarai
# Processing Record 38 of Set 6 | kilindoni
# Processing Record 39 of Set 6 | port victoria
# Processing Record 40 of Set 6 | husavik
# Processing Record 41 of Set 6 | abong mbang
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | eenhana
# Processing Record 44 of Set 6 | toro
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | kaeo
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | micheweni
# Processing Record 49 of Set 6 | ust-ilimsk
# Processing Record 50 of Set 6 | qaqortoq
# Processing Record 1 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 7 | alice springs
# Processing Record 3 of Set 7 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 4 of Set 7 | dese
# Processing Record 5 of Set 7 | bonthe
# Processing Record 6 of Set 7 | charkhi dadri
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | altus
# Processing Record 9 of Set 7 | sinnamary
# Processing Record 10 of Set 7 | christchurch
# Processing Record 11 of Set 7 | iwanai
# Processing Record 12 of Set 7 | stepnyak
# Processing Record 13 of Set 7 | kolondieba
# Processing Record 14 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 7 | fakel
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | oranjemund
# Processing Record 18 of Set 7 | lakatoro
# Processing Record 19 of Set 7 | saryozek
# Processing Record 20 of Set 7 | aykhal
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | behbahan
# Processing Record 24 of Set 7 | komyshnya
# Processing Record 25 of Set 7 | sur
# Processing Record 26 of Set 7 | koslan
# Processing Record 27 of Set 7 | kirovskiy
# Processing Record 28 of Set 7 | lufilufi
# Processing Record 29 of Set 7 | viedma
# Processing Record 30 of Set 7 | chuy
# Processing Record 31 of Set 7 | nyurba
# Processing Record 32 of Set 7 | pacific grove
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | dali
# Processing Record 37 of Set 7 | marsabit
# Processing Record 38 of Set 7 | edgewater
# Processing Record 39 of Set 7 | alizai
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | prabumulih
# Processing Record 42 of Set 7 | adzope
# Processing Record 43 of Set 7 | bilibino
# Processing Record 44 of Set 7 | muisne
# Processing Record 45 of Set 7 | ewo
# Processing Record 46 of Set 7 | shelburne
# Processing Record 47 of Set 7 | banepa
# Processing Record 48 of Set 7 | shelopugino
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | nhulunbuy
# Processing Record 1 of Set 8 | oum hadjer
# Processing Record 2 of Set 8 | klaksvik
# Processing Record 3 of Set 8 | tasiilaq
# Processing Record 4 of Set 8 | grenaa
# Processing Record 5 of Set 8 | ardakan
# Processing Record 6 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 8 | ladushkin
# Processing Record 8 of Set 8 | acuexcomac
# Processing Record 9 of Set 8 | lazaro cardenas
# Processing Record 10 of Set 8 | sorland
# Processing Record 11 of Set 8 | kharp
# Processing Record 12 of Set 8 | islamkot
# Processing Record 13 of Set 8 | dryden
# Processing Record 14 of Set 8 | molina
# Processing Record 15 of Set 8 | maromitsa
# Processing Record 16 of Set 8 | brewster
# Processing Record 17 of Set 8 | sao lourenco do sul
# Processing Record 18 of Set 8 | cabo san lucas
# Processing Record 19 of Set 8 | oksfjord
# Processing Record 20 of Set 8 | melinesti
# Processing Record 21 of Set 8 | shirokiy
# Processing Record 22 of Set 8 | requena
# Processing Record 23 of Set 8 | ganzhou
# Processing Record 24 of Set 8 | borba
# Processing Record 25 of Set 8 | bariadi
# Processing Record 26 of Set 8 | maragogi
# Processing Record 27 of Set 8 | muscat
# Processing Record 28 of Set 8 | jiangyou
# Processing Record 29 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 8 | antanifotsy
# Processing Record 31 of Set 8 | marzuq
# Processing Record 32 of Set 8 | vao
# Processing Record 33 of Set 8 | finnsnes
# Processing Record 34 of Set 8 | ndola
# Processing Record 35 of Set 8 | sakakah
# Processing Record 36 of Set 8 | kalga
# Processing Record 37 of Set 8 | souris
# Processing Record 38 of Set 8 | porgera
# Processing Record 39 of Set 8 | balabac
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 8 | pisco
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | havoysund
# Processing Record 46 of Set 8 | aklavik
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | charyshskoye
# Processing Record 49 of Set 8 | babu
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | tessalit
# Processing Record 2 of Set 9 | nicolas bravo
# Processing Record 3 of Set 9 | fuerte olimpo
# Processing Record 4 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 9 | imbituba
# Processing Record 6 of Set 9 | mpulungu
# Processing Record 7 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 9 | kindersley
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | shupiyan
# Processing Record 12 of Set 9 | aleksandrov gay
# Processing Record 13 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 9 | plover
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | coro
# Processing Record 17 of Set 9 | kisesa
# Processing Record 18 of Set 9 | innisfail
# Processing Record 19 of Set 9 | palasa
# Processing Record 20 of Set 9 | seredka
# Processing Record 21 of Set 9 | corrales
# Processing Record 22 of Set 9 | laela
# Processing Record 23 of Set 9 | morehead
# Processing Record 24 of Set 9 | severobaykalsk
# Processing Record 25 of Set 9 | sobolevo
# Processing Record 26 of Set 9 | bataipora
# Processing Record 27 of Set 9 | vardo
# Processing Record 28 of Set 9 | mahuva
# Processing Record 29 of Set 9 | vanavara
# Processing Record 30 of Set 9 | remedios
# Processing Record 31 of Set 9 | adrar
# Processing Record 32 of Set 9 | chibombo
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | saldanha
# Processing Record 35 of Set 9 | moratuwa
# Processing Record 36 of Set 9 | saint george
# Processing Record 37 of Set 9 | nizhniy tsasuchey
# Processing Record 38 of Set 9 | tazovskiy
# Processing Record 39 of Set 9 | acajutla
# Processing Record 40 of Set 9 | irati
# Processing Record 41 of Set 9 | severnoye
# Processing Record 42 of Set 9 | juegang
# Processing Record 43 of Set 9 | port blair
# Processing Record 44 of Set 9 | havre-saint-pierre
# Processing Record 45 of Set 9 | ruteng
# Processing Record 46 of Set 9 | tagusao
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | tocopilla
# Processing Record 49 of Set 9 | beringovskiy
# Processing Record 50 of Set 9 | besikduzu
# Processing Record 1 of Set 10 | ternate
# Processing Record 2 of Set 10 | zemio
# Processing Record 3 of Set 10 | nhamunda
# Processing Record 4 of Set 10 | plettenberg bay
# Processing Record 5 of Set 10 | hobyo
# Processing Record 6 of Set 10 | empangeni
# Processing Record 7 of Set 10 | jintur
# Processing Record 8 of Set 10 | pauini
# Processing Record 9 of Set 10 | emilio carranza
# Processing Record 10 of Set 10 | tuy hoa
# Processing Record 11 of Set 10 | san quintin
# Processing Record 12 of Set 10 | myaundzha
# Processing Record 13 of Set 10 | stutterheim
# Processing Record 14 of Set 10 | khartoum
# Processing Record 15 of Set 10 | soyo
# Processing Record 16 of Set 10 | dhidhdhoo
# Processing Record 17 of Set 10 | aksarka
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | tadine
# Processing Record 20 of Set 10 | saint anthony
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | port hardy
# Processing Record 23 of Set 10 | broome
# Processing Record 24 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 10 | san juan
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | malanje
# Processing Record 28 of Set 10 | sao gabriel da cachoeira
# Processing Record 29 of Set 10 | touros
# Processing Record 30 of Set 10 | vicuna
# Processing Record 31 of Set 10 | waipawa
# Processing Record 32 of Set 10 | derzhavinsk
# Processing Record 33 of Set 10 | progreso
# Processing Record 34 of Set 10 | cacahoatan
# Processing Record 35 of Set 10 | galveston
# Processing Record 36 of Set 10 | colonia
# Processing Record 37 of Set 10 | kavieng
# Processing Record 38 of Set 10 | slonim
# Processing Record 39 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 10 | pozo colorado
# Processing Record 41 of Set 10 | xacmaz
# Processing Record 42 of Set 10 | kashin
# Processing Record 43 of Set 10 | visnes
# Processing Record 44 of Set 10 | sabang
# Processing Record 45 of Set 10 | bandar maharani
# City not found. Skipping...
# Processing Record 46 of Set 10 | santa isabel
# Processing Record 47 of Set 10 | jiayuguan
# Processing Record 48 of Set 10 | nabire
# Processing Record 49 of Set 10 | charters towers
# Processing Record 50 of Set 10 | manosque
# Processing Record 1 of Set 11 | cayenne
# Processing Record 2 of Set 11 | kiama
# Processing Record 3 of Set 11 | skerries
# Processing Record 4 of Set 11 | keti bandar
# Processing Record 5 of Set 11 | leningradskiy
# Processing Record 6 of Set 11 | walajapet
# Processing Record 7 of Set 11 | riberalta
# Processing Record 8 of Set 11 | kunya
# Processing Record 9 of Set 11 | eyrarbakki
# Processing Record 10 of Set 11 | nadapuram
# Processing Record 11 of Set 11 | bairiki
# Processing Record 12 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 11 | scarborough
# Processing Record 14 of Set 11 | nizhniy odes
# Processing Record 15 of Set 11 | jaisalmer
# Processing Record 16 of Set 11 | faya
# Processing Record 17 of Set 11 | aljezur
# Processing Record 18 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 11 | wajima
# Processing Record 20 of Set 11 | jiblah
# Processing Record 21 of Set 11 | diamantino
# Processing Record 22 of Set 11 | buchanan
# Processing Record 23 of Set 11 | collie
# Processing Record 24 of Set 11 | burns lake
# Processing Record 25 of Set 11 | bell ville
# Processing Record 26 of Set 11 | lebedyan
# Processing Record 27 of Set 11 | deniliquin
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | canico
# Processing Record 30 of Set 11 | sao miguel do araguaia
# Processing Record 31 of Set 11 | gallup
# Processing Record 32 of Set 11 | kargasok
# Processing Record 33 of Set 11 | lavrentiya
# Processing Record 34 of Set 11 | bemidji
# Processing Record 35 of Set 11 | tubuala
# Processing Record 36 of Set 11 | aldan
# Processing Record 37 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 11 | kerchevskiy
# Processing Record 39 of Set 11 | dothan
# Processing Record 40 of Set 11 | college
# Processing Record 41 of Set 11 | kaili
# Processing Record 42 of Set 11 | myitkyina
# Processing Record 43 of Set 11 | san carlos de bariloche
# Processing Record 44 of Set 11 | nurota
# Processing Record 45 of Set 11 | nortelandia
# Processing Record 46 of Set 11 | ponta delgada
# Processing Record 47 of Set 11 | zhirnovsk
# Processing Record 48 of Set 11 | mildura
# Processing Record 49 of Set 11 | kuusamo
# Processing Record 50 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 1 of Set 12 | xuddur
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | ketchikan
# Processing Record 4 of Set 12 | ust-kuyga
# Processing Record 5 of Set 12 | east london
# Processing Record 6 of Set 12 | aitape
# Processing Record 7 of Set 12 | sioux lookout
# Processing Record 8 of Set 12 | bereda
# Processing Record 9 of Set 12 | villiers
# Processing Record 10 of Set 12 | lure
# Processing Record 11 of Set 12 | necochea
# Processing Record 12 of Set 12 | shingu
# Processing Record 13 of Set 12 | wajir
# Processing Record 14 of Set 12 | jadu
# Processing Record 15 of Set 12 | rio grande
# Processing Record 16 of Set 12 | chippewa falls
# Processing Record 17 of Set 12 | maniitsoq
# Processing Record 18 of Set 12 | kharan
# Processing Record 19 of Set 12 | tangancicuaro
# City not found. Skipping...
# Processing Record 20 of Set 12 | maumere
# Processing Record 21 of Set 12 | wuhu
# Processing Record 22 of Set 12 | bontang
# Processing Record 23 of Set 12 | parksville
# Processing Record 24 of Set 12 | san andres
# Processing Record 25 of Set 12 | mandalgovi
# Processing Record 26 of Set 12 | sainte-maxime
# Processing Record 27 of Set 12 | truckee
# Processing Record 28 of Set 12 | hambantota
# Processing Record 29 of Set 12 | shumskiy
# Processing Record 30 of Set 12 | ostrov
# Processing Record 31 of Set 12 | dingle
# Processing Record 32 of Set 12 | manaus
# Processing Record 33 of Set 12 | chumikan
# Processing Record 34 of Set 12 | grindavik
# Processing Record 35 of Set 12 | bom jesus
# Processing Record 36 of Set 12 | flin flon
# Processing Record 37 of Set 12 | bud
# Processing Record 38 of Set 12 | iskateley
# Processing Record 39 of Set 12 | kununurra
# Processing Record 40 of Set 12 | wundanyi
# Processing Record 41 of Set 12 | yar-sale
# Processing Record 42 of Set 12 | ibimirim
# Processing Record 43 of Set 12 | nantucket
# Processing Record 44 of Set 12 | meadow lake
# Processing Record 45 of Set 12 | bismarck
# Processing Record 46 of Set 12 | ishigaki
# Processing Record 47 of Set 12 | tapes
# Processing Record 48 of Set 12 | vangaindrano
# Processing Record 49 of Set 12 | djibo
# Processing Record 50 of Set 12 | la victoria
# Processing Record 1 of Set 13 | mucuri
# Processing Record 2 of Set 13 | isoka
# Processing Record 3 of Set 13 | millau
# Processing Record 4 of Set 13 | mogadishu
# Processing Record 5 of Set 13 | pattani
# Processing Record 6 of Set 13 | vostok
# Processing Record 7 of Set 13 | moroni
# Processing Record 8 of Set 13 | merke
# Processing Record 9 of Set 13 | marrakesh
# Processing Record 10 of Set 13 | porto novo
# Processing Record 11 of Set 13 | gondar
# Processing Record 12 of Set 13 | aras
# Processing Record 13 of Set 13 | mahanoro
# Processing Record 14 of Set 13 | celano
# Processing Record 15 of Set 13 | cap malheureux
# Processing Record 16 of Set 13 | lasa
# Processing Record 17 of Set 13 | namatanai
# Processing Record 18 of Set 13 | ipixuna
# Processing Record 19 of Set 13 | bundaberg
# Processing Record 20 of Set 13 | yamada
# Processing Record 21 of Set 13 | umm lajj
# Processing Record 22 of Set 13 | saint-augustin
# Processing Record 23 of Set 13 | gueret
# Processing Record 24 of Set 13 | kuzino
# Processing Record 25 of Set 13 | abu kamal
# Processing Record 26 of Set 13 | bangassou
# Processing Record 27 of Set 13 | surt
# Processing Record 28 of Set 13 | ambilobe
# Processing Record 29 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 13 | bedford
# Processing Record 31 of Set 13 | canaries
# Processing Record 32 of Set 13 | buraydah
# Processing Record 33 of Set 13 | nuevo progreso
# Processing Record 34 of Set 13 | marsa matruh
# Processing Record 35 of Set 13 | kiunga
# Processing Record 36 of Set 13 | ust-karsk
# Processing Record 37 of Set 13 | timbakion
# City not found. Skipping...
# Processing Record 38 of Set 13 | ninh binh
# Processing Record 39 of Set 13 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 40 of Set 13 | tarbagatay
# Processing Record 41 of Set 13 | cidreira
# Processing Record 42 of Set 13 | vieux-habitants
# Processing Record 43 of Set 13 | palmas
# Processing Record 44 of Set 13 | esso
# Processing Record 45 of Set 13 | bambanglipuro
# Processing Record 46 of Set 13 | sarangani
# Processing Record 47 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 13 | tselinnoye
# Processing Record 49 of Set 13 | kaka
# Processing Record 50 of Set 13 | igarka
# Processing Record 1 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 14 | zainsk
# Processing Record 4 of Set 14 | biskamzha
# Processing Record 5 of Set 14 | rindal
# Processing Record 6 of Set 14 | irbil
# Processing Record 7 of Set 14 | kristiansund
# Processing Record 8 of Set 14 | yekaterinoslavka
# Processing Record 9 of Set 14 | lakes entrance
# Processing Record 10 of Set 14 | west fargo
# Processing Record 11 of Set 14 | makokou
# Processing Record 12 of Set 14 | sambava
# Processing Record 13 of Set 14 | lypnyazhka
# Processing Record 14 of Set 14 | odweyne
# Processing Record 15 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | kaspiyskiy
# Processing Record 17 of Set 14 | nelson bay
# Processing Record 18 of Set 14 | dalkola
# Processing Record 19 of Set 14 | tigzirt
# Processing Record 20 of Set 14 | conde
# Processing Record 21 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 14 | pokrovsk
# Processing Record 23 of Set 14 | berlevag
# Processing Record 24 of Set 14 | yeniseysk
# Processing Record 25 of Set 14 | hiranagar
# Processing Record 26 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 27 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 14 | okato
# Processing Record 29 of Set 14 | leua
# Processing Record 30 of Set 14 | mount gambier
# Processing Record 31 of Set 14 | wenshang
# Processing Record 32 of Set 14 | varhaug
# Processing Record 33 of Set 14 | raiganj
# Processing Record 34 of Set 14 | westport
# Processing Record 35 of Set 14 | birao
# Processing Record 36 of Set 14 | buluang
# Processing Record 37 of Set 14 | walvis bay
# Processing Record 38 of Set 14 | traverse city
# Processing Record 39 of Set 14 | morondava
# Processing Record 40 of Set 14 | vizantea
# City not found. Skipping...
# Processing Record 41 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 14 | anadyr
# Processing Record 43 of Set 14 | chabahar
# Processing Record 44 of Set 14 | goderich
# Processing Record 45 of Set 14 | palana
# Processing Record 46 of Set 14 | matagami
# Processing Record 47 of Set 14 | okha
# Processing Record 48 of Set 14 | kyshtovka
# Processing Record 49 of Set 14 | santa fe
# Processing Record 50 of Set 14 | arroyo
# Processing Record 1 of Set 15 | toora-khem
# Processing Record 2 of Set 15 | iquitos
# Processing Record 3 of Set 15 | bridlington
# Processing Record 4 of Set 15 | berezovyy
# Processing Record 5 of Set 15 | bathsheba
# Processing Record 6 of Set 15 | millinocket
# Processing Record 7 of Set 15 | khagrachari
# City not found. Skipping...
# Processing Record 8 of Set 15 | pergamino
# Processing Record 9 of Set 15 | manoel urbano
# Processing Record 10 of Set 15 | salinas
# Processing Record 11 of Set 15 | manado
# Processing Record 12 of Set 15 | tomatlan
# Processing Record 13 of Set 15 | presidencia roque saenz pena
# Processing Record 14 of Set 15 | payo
# Processing Record 15 of Set 15 | maun
# Processing Record 16 of Set 15 | huambo
# Processing Record 17 of Set 15 | kpandu
# Processing Record 18 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 15 | arucas
# Processing Record 20 of Set 15 | diphu
# Processing Record 21 of Set 15 | maneromango
# Processing Record 22 of Set 15 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 661

# %%
# Convert the array of dictionaries to a Pandas DataFrame:
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Rikitea -23.1203 -134.9692     70.88        63          74       21.34
# 1    Zyryanka  65.7500  150.8500     47.71        94         100        6.08
# 2  Santa Rosa  14.3122  121.1114     76.98        96         100        4.56
# 3  Codrington -38.2667  141.9667     41.68        97          11        7.07
# 4       Nyrob  60.7330   56.7202     65.07        68          84        2.19
# 5      Dikson  73.5069   80.5464     45.30        93          93       17.13
# 6  Sergeyevka  53.8800   67.4158     66.15        63          25        1.99
# 7   Busselton -33.6500  115.3333     52.59        78          96        0.51
# 8      Hasaki  35.7333  140.8333     72.28        75         100        9.64
# 9      Sasovo  54.3537   41.9199     73.78        59          92        5.70
#
#   Current Description Country
# 0       broken clouds      PF
# 1     overcast clouds      RU
# 2       moderate rain      PH
# 3          few clouds      AU
# 4       broken clouds      RU
# 5     overcast clouds      RU
# 6    scattered clouds      KZ
# 7     overcast clouds      AU
# 8     overcast clouds      JP
# 9     overcast clouds      RU

# %%
#New column order:
new_column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Rikitea      PF -23.1203 -134.9692     70.88        63          74
# 1    Zyryanka      RU  65.7500  150.8500     47.71        94         100
# 2  Santa Rosa      PH  14.3122  121.1114     76.98        96         100
# 3  Codrington      AU -38.2667  141.9667     41.68        97          11
# 4       Nyrob      RU  60.7330   56.7202     65.07        68          84
#
#    Wind Speed Current Description
# 0       21.34       broken clouds
# 1        6.08     overcast clouds
# 2        4.56       moderate rain
# 3        7.07          few clouds
# 4        2.19       broken clouds

# %%
# Create the output file (CSV):
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV:
city_data_df.to_csv(output_data_file, index_label="City_ID")
